# %%
from Korpora import Korpora
Korpora.fetch("namuwikitext", root_dir='wiki.text')
# Out:
# [Korpora] Corpus `namuwikitext` is already installed at c:\skn_17\nlp\03_word_embedding\wiki.text\namuwikitext\namuwikitext_20200302.train.zip
# [Korpora] Corpus `namuwikitext` is already installed at c:\skn_17\nlp\03_word_embedding\wiki.text\namuwikitext\namuwikitext_20200302.train
# [Korpora] Corpus `namuwikitext` is already installed at c:\skn_17\nlp\03_word_embedding\wiki.text\namuwikitext\namuwikitext_20200302.test.zip
# [Korpora] Corpus `namuwikitext` is already installed at c:\skn_17\nlp\03_word_embedding\wiki.text\namuwikitext\namuwikitext_20200302.test
# [Korpora] Corpus `namuwikitext` is already installed at c:\skn_17\nlp\03_word_embedding\wiki.text\namuwikitext\namuwikitext_20200302.dev.zip
# [Korpora] Corpus `namuwikitext` is already installed at c:\skn_17\nlp\03_word_embedding\wiki.text\namuwikitext\namuwikitext_20200302.dev

# %%
import pandas as pd

wiki = pd.read_csv("./wnamuwikitext_20200302.deviki.text/namuwikitext/", sep="\t", header=None)
wiki.head()
# len(wiki)
# Out:
#                                                    0
# 0                                    = 에일리언: 컨테인먼트 =
# 1  Alien: Containment. 에이리언 1편 40주년을 맞아 2019년 3월에...
# 2      참고로 우연의 일치인지 컨테인먼트라는 단어 자체가 에이리언: 커버넌트와 유사하다.
# 3                                = Exiled Kingdoms =
# 4                                         = = 개요 = =

# %%
wiki[0].isnull().sum()
# Out:
# 0

# %%
wiki[0] = wiki[0].replace(r'[^가-힣ㄱ-ㅎㅏ-ㅣ\s]', '', regex=True)

# %%
wiki[0]
# Out:
# 0                                               에일리언 컨테인먼트
# 1           에이리언 편 주년을 맞아 년 월에 공개된 분 초짜리 단편으로 목성형 행성을 지나...
# 2               참고로 우연의 일치인지 컨테인먼트라는 단어 자체가 에이리언 커버넌트와 유사하다
# 3
# 4                                                      개요
#                                 ...
# 117992    합체 시 조종석은 한 군데로 모이지 않으며 일괄적으로 조종하는 것이 아닌 각 부위에...
# 117993    현재까지 수많은 전투를 벌였지만 단 한번도 패배한 적이 없는 무적의 메카이다 이는 ...
# 117994                                              같이 보기
# 117995                                    역대 자유 인도 임시정부 주석
# 117996
# Name: 0, Length: 117997, dtype: object

# %%
from konlpy.tag import Okt
from tqdm import tqdm

okt = Okt()

def load_stopwords(filepath):
    with open(filepath, 'r', encoding='UTF-8') as f :
        stopwords = [line.strip() for line in f]          # strip : 앞뒤 공백 제거 
    return stopwords

ko_stopwords = load_stopwords('ko_stopwords.txt')

preprocess_data = []

for sentence in tqdm(wiki[0]) :   
    tokens = okt.morphs(sentence, stem=True)
    tokens = [token for token in tokens if token not in ko_stopwords]
    tokens = [token for token in tokens if len(token) > 2]
    preprocess_data.append(tokens)

preprocess_data[100:300]
# Out:
# 100%|██████████| 117997/117997 [04:31<00:00, 434.14it/s]
# [['아이템',
#   '스크롤',
#   '올려주다',
#   '저항력',
#   '올려주다',
#   '올려주다',
#   '투명하다',
#   '해주다',
#   '바르다',
#   '해주다',
#   '어렵다',
#   '해주다',
#   '괜찮다',
#   '해주다',
#   '스크롤',
#   '순간이동',
#   '순간이동',
#   '스크롤'],
#  [],
#  ['평범하다',
#   '아이템',
#   '캐릭터',
#   '강화하다',
#   '싸우다',
#   '입히다',
#   '난이도',
#   '아니다',
#   '플레이어',
#   '따르다',
#   '가까이',
#   '따라오다',
#   '에서는',
#   '완전하다',
#   '벗어나다',
#   '쫓아오다',
#   '플레이어',
#   '바뀌다',
#   '조금씩',
#   '안전하다',
#   '레이스',
#   '고스트'],
#  ['상당하다',
#   '강력하다',
#   '상대로',
#   '아니다',
#   '불가능하다',
#   '조금씩',
#   '아나가야',
#   '몰리다',
#   '난이도',
#   '안되다',
#   '어리다',
#   '따르다',
#   '나가다',
#   '저항력',
#   '늘리다',
#   '저항력',
#   '올려주다',
#   '저항력',
#   '저항력',
#   '챙기다'],
#  ['숨기다',
#   '경험치',
#   '올리다',
#   '어리다',
#   '맞추다',
#   '네가지',
#   '채우다',
#   '마지막',
#   '아니다',
#   '파란색',
#   '나오다',
#   '나오다',
#   '이렇다',
#   '맞추다',
#   '해주다',
#   '대부분',
#   '숨기다',
#   '가능하다',
#   '비밀방',
#   '퀘스트'],
#  [],
#  ['에서의', '자유롭다', '아니다', '마법사', '순간이동', '비싸다', '걸리다', '자유롭다'],
#  ['마법사',
#   '스크롤',
#   '순간이동',
#   '스크롤',
#   '스크롤',
#   '그리다',
#   '비싸다',
#   '가깝다',
#   '순간이동',
#   '순간이동',
#   '스크롤',
#   '비싸다',
#   '괜찮다',
#   '마법사',
#   '순간이동',
#   '배우다'],
#  ['열리다', '으로의', '순간이동', '순간이동', '스크롤'],
#  ['퀘스트'],
#  ['퀘스트', '다양하다', '퀘스트', '새롭다', '퀘스트', '이동해'],
#  ['퀘스트',
#   '퀘스트',
#   '되어다',
#   '퀘스트',
#   '주기도',
#   '퀘스트',
#   '퀘스트',
#   '단순하다',
#   '달라지다',
#   '퀘스트',
#   '바뀌다',
#   '소소하다',
#   '미치다',
#   '선하다',
#   '퀘스트',
#   '퀘스트',
#   '아니다',
#   '어렵다',
#   '퀘스트',
#   '에서의',
#   '따르다',
#   '달라지다',
#   '해보다',
#   '책임지다'],
#  ['대부분',
#   '플레이어',
#   '따르다',
#   '달라지다',
#   '단순하다',
#   '끝나다',
#   '대부분',
#   '퀘스트',
#   '바꾸다',
#   '해주다',
#   '골고루',
#   '올려주다',
#   '괴롭히다',
#   '들어오다',
#   '퀘스트'],
#  ['퀘스트', '퀘스트', '그리다', '부족하다', '퀘스트', '보스나', '유실물', '아니다', '플레이어'],
#  [],
#  ['거주지', '에서는', '완전하다', '아니다', '저렴하다'],
#  ['에서는', '아이템', '올리다', '퀘스트', '으로만', '주기도', '퀘스트', '퀘스트', '되어다'],
#  [],
#  ['에서나', '편리하다', '아이템', '챙기다'],
#  ['에서만', '더하다'],
#  ['더하다', '순간이동'],
#  ['이르다', '만들다', '해주다', '나머지', '퀘스트', '해주다'],
#  [],
#  ['다니다',
#   '캐릭터',
#   '퀘스트',
#   '캐릭터',
#   '싸우다',
#   '되어다',
#   '퀘스트',
#   '캐릭터',
#   '마찬가지',
#   '퀘스트',
#   '실패하다'],
#  ['스토리',
#   '플레이어',
#   '캐릭터',
#   '다니다',
#   '늘리다',
#   '쓰러지다',
#   '살아나다',
#   '플레이어',
#   '캐릭터',
#   '경험치',
#   '트레잇',
#   '올려주다'],
#  ['플레이어',
#   '캐릭터',
#   '경험치',
#   '정해진',
#   '트레잇',
#   '포인트',
#   '되어다',
#   '트레잇',
#   '포인트',
#   '높아지다',
#   '플레이어',
#   '캐릭터',
#   '벌어지다',
#   '배우다',
#   '퀘스트',
#   '배우다',
#   '퀘스트',
#   '포인트',
#   '포인트',
#   '주어지다'],
#  ['다니다',
#   '경험치',
#   '나누다',
#   '플레이어',
#   '캐릭터',
#   '경험치',
#   '플레이어',
#   '캐릭터',
#   '경험치',
#   '아니다',
#   '퀘스트',
#   '경험치',
#   '경험치',
#   '보너스',
#   '플레이어',
#   '캐릭터',
#   '보너스',
#   '경험치',
#   '플레이어',
#   '캐릭터',
#   '경험치',
#   '다니다',
#   '경험치',
#   '플레이어',
#   '경험치',
#   '부족하다',
#   '경험치',
#   '경험치',
#   '플레이어',
#   '내려가다',
#   '다니다',
#   '플레이어',
#   '차이나다',
#   '번갈아'],
#  [],
#  ['클래스', '만나다', '주인공', '뒤통수', '달아나다', '빈털터리', '에서부터', '만들다'],
#  ['퀘스트', '갇히다', '꺼내다', '꺼내다', '버리다'],
#  ['데미지', '약하다', '힘드다', '캐릭터', '올리다', '원거리'],
#  ['데미지', '엄청나다', '해주다', '해주다', '순식간', '몬스터'],
#  ['마법사', '마법사', '반갑다', '해주다'],
#  ['그리다'],
#  ['클래스', '개척지', '이라는'],
#  ['주인공',
#   '가져오다',
#   '가져오다',
#   '돌려주다',
#   '괜찮다',
#   '버리다',
#   '어차피',
#   '따라다니다',
#   '쿨하다',
#   '넘겨주다',
#   '받아들이다'],
#  ['에서는',
#   '한다는',
#   '시너지',
#   '키우다',
#   '묵직하다',
#   '노리다',
#   '이리저리',
#   '버리다',
#   '들이다',
#   '쪼개다',
#   '순식간',
#   '녹이다',
#   '버리다',
#   '키우다'],
#  ['버리다'],
#  [],
#  ['성직자',
#   '클래스',
#   '한가운데',
#   '언데드',
#   '해오다',
#   '상당하다',
#   '난이도',
#   '단단하다',
#   '돌아오다',
#   '주인공',
#   '따라오다'],
#  ['어정쩡하다',
#   '성직자',
#   '키우다',
#   '어렵다',
#   '쿨타임',
#   '지나다',
#   '되어다',
#   '버리다',
#   '나서다',
#   '메이스',
#   '버프스킬',
#   '으로의',
#   '퀘스트',
#   '초심자',
#   '다니다',
#   '새롭다',
#   '새롭다',
#   '헤매다',
#   '들이키다',
#   '다니다',
#   '안되다',
#   '다니다',
#   '아끼다',
#   '풀세팅',
#   '그리다',
#   '다르다',
#   '마음껏',
#   '클리어',
#   '성직자',
#   '언데드',
#   '들어가다',
#   '플레이어',
#   '아이템',
#   '충분하다',
#   '강하다',
#   '길어지다',
#   '무조건',
#   '다니다',
#   '성직자',
#   '약하다',
#   '트레잇',
#   '포인트'],
#  ['어리다', '퀘스트', '챙기다', '퀘스트'],
#  ['클래스'],
#  ['클래스', '성직자', '마법사', '나뉘어지다'],
#  ['별다르다', '요구사항', '만으로도', '배우다', '요구사항', '만족하다', '포인트', '배우다'],
#  [],
#  ['흔하다', '쿨타임', '때리다', '플레이', '편하다'],
#  [],
#  [],
#  [],
#  ['판금갑'],
#  ['메이스', '손도끼'],
#  [],
#  [],
#  ['입히다', '밀치다', '몰리다', '용이하다', '마스터', '포인트', '여기저기', '흩어지다', '쪼개다', '나쁘다'],
#  [],
#  ['보너스', '올리다', '쿨타임', '쿨타임'],
#  [],
#  ['공격기', '빠르다', '대미지', '마스터', '쿨타임', '쏠쏠하다', '대미지', '지나가다', '그리다', '유일하다'],
#  [],
#  ['아이덴티티'],
#  ['이하일', '대미지', '마스터', '이하일', '대미지', '마스터', '엄청나다'],
#  [],
#  ['기르다', '기르다', '성직자', '만큼은', '확실하다', '기르다', '마스터', '데미지', '되어다'],
#  [],
#  ['도르다',
#   '원거리',
#   '도르다',
#   '무조건',
#   '마스터',
#   '기르다',
#   '원거리',
#   '강하다',
#   '되어다',
#   '싸우다',
#   '단단하다',
#   '해보다'],
#  ['원거리', '마스터', '원거리', '생기다', '원거리', '해오다'],
#  [],
#  ['밀치다', '달려오다', '몬스터', '무용지물', '만들다', '훨윈드', '당하다'],
#  ['쪼개다'],
#  ['아이덴티티'],
#  ['들어오다',
#   '사거리',
#   '들어오다',
#   '약하다',
#   '때리다',
#   '마스터',
#   '되어다',
#   '가하다',
#   '나머지',
#   '기르다',
#   '빠르다',
#   '마스터',
#   '달려들다',
#   '심해지다',
#   '빠르다'],
#  [],
#  ['흔하다', '빠르다', '스타일', '경험치'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['메이스'],
#  [],
#  [],
#  ['활쏘기', '데미지', '입히다'],
#  ['마스터', '합치다'],
#  [],
#  [],
#  ['살아나다', '쿨타임', '필요하다', '필요하다'],
#  ['발차기'],
#  ['밀치다', '느리다', '흐트러뜨리거', '도망치다', '딱이다'],
#  ['살아나다', '쿨타임', '충분하다'],
#  [],
#  ['노리다', '데미지', '가하다'],
#  [],
#  [],
#  ['아드레날린', '이동속도', '이동속도', '올라가다'],
#  ['에서는', '당하다'],
#  ['찌르다'],
#  [],
#  ['부터는', '데미지', '들어가다', '무시무시하다', '강하다'],
#  [],
#  ['들키다', '가까이', '알아채다'],
#  ['찌르다', '마찬가지', '에서는', '어려워지다', '들키다', '에서는', '불가능하다'],
#  [],
#  [],
#  ['걸리다',
#   '느리다',
#   '쿨타임',
#   '발차기',
#   '돌아오다',
#   '도망치다',
#   '충분하다',
#   '활쏘기',
#   '발차기',
#   '활쏘기',
#   '발차기'],
#  ['성직자'],
#  ['클래스', '난이도', '워리어', '부족하다', '플레이', '어렵다'],
#  [],
#  [],
#  [],
#  [],
#  ['버리다'],
#  [],
#  ['판금갑'],
#  ['메이스'],
#  [],
#  [],
#  ['회복하다', '회복량', '돌아가다', '늘어나다', '갈수록', '가깝다', '힘들다', '가깝다', '올려놓다'],
#  ['신성하다'],
#  ['생기다', '워리어', '순식간', '바닥나다', '쿨타임', '버프들', '두르다', '필요하다'],
#  ['신성하다'],
#  ['애매하다', '유일하다', '액티브형', '데미지', '마스터', '언데드', '데미지', '여전하다', '보다는', '신성하다'],
#  [],
#  ['끼어들다', '그만큼', '마스터', '그렇게', '필요하다'],
#  [],
#  ['강화하다', '올라가다', '입히다', '버프형', '액티브', '올라가다', '데미지'],
#  [],
#  ['언데드',
#   '으로는',
#   '데미지',
#   '언데드',
#   '몬스터',
#   '마스터',
#   '대미지',
#   '애매하다',
#   '성직자',
#   '두르다',
#   '다니다',
#   '휘두르다',
#   '몬스터',
#   '어렵다',
#   '웬만하다',
#   '언데드',
#   '몬스터',
#   '따지다',
#   '마스터',
#   '언데드',
#   '헤매다',
#   '성직자',
#   '마스터',
#   '언데드',
#   '끝나다',
#   '팔라딘',
#   '롱소드',
#   '합치다',
#   '나가다'],
#  [],
#  ['언데드', '가지다', '마스터', '언데드'],
#  ['워리어', '특별하다', '필요없다', '두르다', '나오다', '포인트', '들어가다', '마스터'],
#  [],
#  ['빌리다',
#   '찾아내다',
#   '스크롤',
#   '마스터',
#   '숨기다',
#   '찾아내다',
#   '스크롤',
#   '마스터',
#   '엄청나다',
#   '마스터',
#   '성직자'],
#  ['마법사'],
#  ['올리다', '퀘스트', '경험치', '데미지'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['스태프'],
#  [],
#  [],
#  ['라이트닝'],
#  ['일직선',
#   '날리다',
#   '빠지다',
#   '워리어',
#   '때리다',
#   '월등하다',
#   '올리다',
#   '데미지',
#   '사랑받다',
#   '마스터',
#   '마스터',
#   '쿨타임'],
#  ['파이어'],
#  ['그대로',
#   '구르다',
#   '날리다',
#   '데미지',
#   '데미지',
#   '잡아먹다',
#   '라이트닝',
#   '데미지',
#   '아니다',
#   '떨구다',
#   '데미지',
#   '이동속도',
#   '빠르다',
#   '나가다',
#   '나오다',
#   '유일하다',
#   '데미지',
#   '가까이',
#   '파이어',
#   '버리다',
#   '에게는',
#   '데미지',
#   '들어가다',
#   '쿨타임',
#   '올라가다',
#   '치솟다',
#   '커지다'],
#  ['아이스'],
#  ['눈보라', '해내다', '눈보라', '데미지', '눈보라', '바라보다', '이리저리', '버리다', '쿨타임'],
#  ['메이지'],
#  ['마법사', '부족하다', '채우다', '가지다'],
#  ['사라지다', '상당하다', '가능하다', '지나다', '사라지다', '두르다'],
#  ['데미지', '들어주다', '사라지다', '굉장하다', '유용하다'],
#  ['부터는', '저항력', '높이다'],
#  ['데미지', '아니다', '순수하다', '원거리', '던지다', '불덩이', '메이지', '사라지다'],
#  ['배우다'],
#  ['메이지', '아니다', '사하다', '메이지', '이라도', '쿨타임'],
#  ['마스터'],
#  ['마법사', '원거리', '데미지', '따르다', '데미지', '해주다', '이어도', '마법사', '유용하다'],
#  ['스태프', '마스터'],
#  ['마법사',
#   '원거리',
#   '스태프',
#   '데미지',
#   '따르다',
#   '데미지',
#   '슬로우',
#   '해주다',
#   '마법사',
#   '캐릭터',
#   '아이템',
#   '더하다',
#   '보다는',
#   '스태프'],
#  [],
#  ['보너스', '캐릭터', '키우다', '마스터', '되어다', '그렇다', '포인트'],
#  [],
#  ['마스터', '늘리다', '마스터', '따르다', '액티브', '올라가다', '늘어나다', '성급하다', '올리다'],
#  [],
#  [],
#  [],
#  ['스태프',
#   '이라는',
#   '되어다',
#   '한다는',
#   '줄이다',
#   '강력하다',
#   '스태프',
#   '일수록',
#   '배우다',
#   '마법사',
#   '최대한',
#   '플레이',
#   '중요하다'],
#  [],
#  ['마법사',
#   '에게는',
#   '강력하다',
#   '날리다',
#   '그만큼',
#   '따르다',
#   '데미지',
#   '사라지다',
#   '사용자',
#   '따르다',
#   '호불호',
#   '대단하다',
#   '저항력',
#   '상당하다',
#   '유용하다',
#   '올리다',
#   '뒤지다',
#   '쿨타임'],
#  ['마스터'],
#  ['소환빌드', '마법사', '마스터', '아니다', '나오다', '지르다', '든든하다'],
#  ['파이어', '마스터'],
#  [],
#  ['아이스', '마스터'],
#  [],
#  ['가능하다'],
#  [],
#  ['올려주다', '포인트', '마법사', '클레릭', '배우다'],
#  ['메이지'],
#  ['메이지',
#   '메이지',
#   '두르다',
#   '플레이어',
#   '데미지',
#   '배우다',
#   '메이지',
#   '기대하다',
#   '메이지',
#   '올리다',
#   '들어가다',
#   '포인트',
#   '그렇다',
#   '뒤통수',
#   '벌리다',
#   '싸우다',
#   '마법사',
#   '시너지'],
#  ['순간이동'],
#  ['마법사',
#   '플레이',
#   '클레릭',
#   '배우다',
#   '가깝다',
#   '가능하다',
#   '해주다',
#   '스크롤',
#   '챙기다',
#   '귀찮다',
#   '사냥터',
#   '포인트',
#   '포인트',
#   '기꺼이',
#   '순간이동',
#   '아이템',
#   '퀘스트',
#   '잽싸다',
#   '퀘스트',
#   '아이템',
#   '빠져나오다',
#   '가능하다',
#   '플레이',
#   '스크롤',
#   '하므다',
#   '채널링',
#   '드리다',
#   '싸늘하다'],
#  [],
#  [],
#  ['클래스', '동일하다'],
#  [],
#  ['되어다', '숨기다', '찾아내다'],
#  ['스크롤', '성직자', '웬만하다', '걸리다', '짜증나다', '배우다', '여전하다'],
#  [],
#  [],
#  ['아니다', '에서도', '가능하다', '해주다', '가능하다'],
#  ['올리다', '포인트', '필요하다', '포인트', '차오르다', '길어지다', '모자라다'],
#  [],
#  ['친해지다'],
#  ['퀘스트', '알아내다', '들어가다', '걸리다', '안되다', '망설이다', '성직자', '대인관계', '플레이어'],
#  []]

# %%
nouns_per_sentence = [
    [w for w,t in okt.pos(" ".join(s), norm=True, stem=True) if t=='Noun']
    for s in preprocess_data
]
nouns_per_sentence = [ns for ns in nouns_per_sentence if ns]  # 빈 리스트 제거

# %%
nouns_per_sentence[:10]
# Out:
# [['에일리언', '컨테인먼트'],
#  ['에이리언', '우주선', '동강이', '버스터', '줄거리', '스포일러', '혼수상태', '산소마스크', '생채기', '난장판'],
#  ['컨테인먼트', '에이리언', '커버', '넌트'],
#  ['롤플레잉', '모바일'],
#  ['페이지'],
#  ['모바일', '체험판', '성직자', '마법사', '플레이', '퀘스트', '퀘스트', '퀘스트'],
#  ['체험판', '컨텐츠', '제작자'],
#  ['플레이'],
#  ['스토리'],
#  ['식민지']]

# %%
len(nouns_per_sentence)
# Out:
# 74709

# %%
from gensim.models import FastText

wiki_model = FastText(        
    sentences= nouns_per_sentence, 
    vector_size=300, 
    window=5, 
    min_count=10, 
    sg=1,
    negative=10, 
    sample=1e-5, 
    epochs=10, 
    min_n=2, 
    max_n=3
)

# %%
wiki_model.wv.vectors.shape
# Out:
# (5768, 300)

# %%
wiki_model.wv.most_similar('마법사', topn=100)
# Out:
# [('코마츠', 0.9987637400627136),
#  ('에게까지', 0.9986202120780945),
#  ('하이델룬', 0.9986073970794678),
#  ('그다지', 0.998471200466156),
#  ('어드밴티', 0.9984509944915771),
#  ('마법진', 0.9984490275382996),
#  ('어셈블리', 0.9984242916107178),
#  ('마무리', 0.9984224438667297),
#  ('포켓몬', 0.9984021782875061),
#  ('제대로', 0.9983952641487122),
#  ('황무지', 0.9983728528022766),
#  ('하루히', 0.9983684420585632),
#  ('싸이코', 0.9983019232749939),
#  ('드라고', 0.9982982277870178),
#  ('제멋대로', 0.9982749819755554),
#  ('에게로', 0.9982560276985168),
#  ('세리카', 0.9982442259788513),
#  ('도무지', 0.9982320070266724),
#  ('제갈량', 0.998215913772583),
#  ('그동안', 0.9981774687767029),
#  ('바가지', 0.9981738328933716),
#  ('그야말로', 0.998143196105957),
#  ('에게서', 0.998137354850769),
#  ('어차피', 0.9980776309967041),
#  ('제자리', 0.9980770945549011),
#  ('에게는', 0.9980221390724182),
#  ('순식간', 0.9980193376541138),
#  ('어딘가', 0.9979478120803833),
#  ('브리트라', 0.9978740215301514),
#  ('마지막', 0.9977719187736511),
#  ('호르몬', 0.9977521300315857),
#  ('싸가지', 0.9977356791496277),
#  ('바라지', 0.9976794719696045),
#  ('어김없이', 0.9976218342781067),
#  ('무지막지', 0.9975817799568176),
#  ('모조리', 0.9975453615188599),
#  ('옆구리', 0.997531533241272),
#  ('데미안', 0.9974609017372131),
#  ('어거지', 0.9974271059036255),
#  ('도깨비', 0.9974122047424316),
#  ('살라딘', 0.9973923563957214),
#  ('그대로', 0.9973855018615723),
#  ('하루하루', 0.9971327781677246),
#  ('너구리', 0.997112512588501),
#  ('도라지', 0.9970927238464355),
#  ('방향키', 0.9970893859863281),
#  ('에게나', 0.99705970287323),
#  ('어쩐지', 0.9970391988754272),
#  ('짊어지', 0.9970344305038452),
#  ('할아버지', 0.9970118403434753),
#  ('항아리', 0.9969943165779114),
#  ('친아버지', 0.9969910979270935),
#  ('호기심', 0.996978223323822),
#  ('어쩌다가', 0.9969495534896851),
#  ('미스티', 0.9969077706336975),
#  ('가만히', 0.996889591217041),
#  ('나뭇가지', 0.9968860149383545),
#  ('마사미', 0.9968506693840027),
#  ('어드밴티지', 0.9968143105506897),
#  ('제풀이', 0.9967207908630371),
#  ('끝없이', 0.996712863445282),
#  ('난데없이', 0.9966971278190613),
#  ('양아버지', 0.9966790676116943),
#  ('그러다가', 0.9966464042663574),
#  ('하고는', 0.9966217279434204),
#  ('마도카', 0.9965469837188721),
#  ('케르츠', 0.996543288230896),
#  ('쌍둥이', 0.9964749813079834),
#  ('츤데레', 0.9964746832847595),
#  ('멍청이', 0.9964457154273987),
#  ('덩어리', 0.9963971972465515),
#  ('뱌쿠야', 0.9963927865028381),
#  ('최대로', 0.9963603019714355),
#  ('마음껏', 0.9963586926460266),
#  ('게아재비', 0.9963489174842834),
#  ('멋대로', 0.9963415265083313),
#  ('잠자리', 0.9963204860687256),
#  ('난쟁이', 0.9963133335113525),
#  ('가까이', 0.9962275624275208),
#  ('달팽이', 0.9961978197097778),
#  ('발레리', 0.9961965680122375),
#  ('루시엔', 0.9961901903152466),
#  ('웃음소리', 0.9961529970169067),
#  ('미치코', 0.9961472749710083),
#  ('병아리', 0.9961339831352234),
#  ('그렇게', 0.9961115121841431),
#  ('하나같이', 0.9961094260215759),
#  ('여자아이', 0.9961026906967163),
#  ('손가락', 0.9961012005805969),
#  ('돌멩이', 0.9960481524467468),
#  ('바다로', 0.9960430860519409),
#  ('마시기', 0.9960423707962036),
#  ('할머니', 0.9960380792617798),
#  ('어디가', 0.9960266351699829),
#  ('미도리', 0.9960139393806458),
#  ('바람둥이', 0.9959972500801086),
#  ('울음소리', 0.9959849119186401),
#  ('목소리', 0.995969831943512),
#  ('엉덩이', 0.9959476590156555),
#  ('미카즈키', 0.9959309101104736)]

# %%
import random
from gensim.models import FastText

model = wiki_model  # 이미 학습된 FastText 모델 객체를 사용한다고 가정

# ---------------------------
# 유틸 함수들
# ---------------------------
def is_in_vocab(w):
    return w in model.wv.key_to_index

def random_word(exclude=set(), min_len=2):
    keys = model.wv.key_to_index.keys()
    while True:
        w = random.choice(list(keys))
        if (w not in exclude) and (len(w) >= min_len):
            return w

def sample_pair_with_similarity(threshold=0.8, max_tries=5000):
    """
    유사도 >= threshold인 (A,B) 한 쌍을 무작위로 뽑는다.
    """
    keys = list(model.wv.key_to_index.keys())
    for _ in range(max_tries):
        A = random.choice(keys)
        B = random.choice(keys)
        if A == B:
            continue
        sim = model.wv.similarity(A, B)
        if sim >= threshold:
            return A, B, sim
    raise RuntimeError(f"유사도>={threshold}인 쌍을 찾지 못했습니다. (max_tries={max_tries}): threshold를 낮춰보세요.")

def sample_C(exclude, max_tries=2000):
    """
    A,B와 너무 겹치지 않는 C를 뽑는다.
    """
    keys = list(model.wv.key_to_index.keys())
    for _ in range(max_tries):
        C = random.choice(keys)
        if C not in exclude and len(C) >= 2:
            return C
    raise RuntimeError("C를 뽑지 못했습니다.")

def compute_D_candidates(A, B, C, topn=10):
    """
    벡터 연산 B - A + C로 D 후보들을 구한다.
    A,B,C 자체는 제외.
    """
    candidates = model.wv.most_similar(positive=[B, C], negative=[A], topn=topn)
    filtered = [(w, s) for w, s in candidates if w not in {A, B, C}]
    return filtered

# ---------------------------
# 게임 본체
# ---------------------------
def play_analogy_game(rounds=5, sim_threshold=0.8, topn=10):
    print("== 단어 유추 게임 시작 ==")
    print("형식:  A : B  =  C : D  → D를 맞혀보세요!\n")
    score = 0

    for r in range(1, rounds+1):
        # 1) (A,B) 샘플링 (유사도 >= threshold)
        try:
            A, B, ab_sim = sample_pair_with_similarity(threshold=sim_threshold)
        except RuntimeError as e:
            print(e)
            break

        # 2) C 샘플링
        C = sample_C(exclude={A, B})

        # 3) D 후보 계산
        D_candidates = compute_D_candidates(A, B, C, topn=topn)
        if not D_candidates:
            # 후보가 없다면 라운드 재시도
            # (데이터가 작거나 희귀어가 많을 때 발생 가능)
            continue
        D_true, D_score = D_candidates[0]  # 정답 후보 1위

        # 4) 문제 제시
        print(f"[Round {r}]  {A} : {B}  =  {C} : ?")
        guess = input("당신의 답 D: ").strip()

        # 5) 판정
        correct_set = {w for w, _ in D_candidates[:3]}  # 상위 3개까지 정답 인정(난이도 조절)
        if guess in correct_set:
            print(f"✅ 정답! (정답 후보: {D_true}, 상위 후보: {', '.join(correct_set)})\n")
            score += 1
        else:
            print(f"❌ 오답!  정답 후보: {D_true}")
            print(f"   상위 후보들: {', '.join([w for w,_ in D_candidates[:5]])}\n")

    print(f"== 게임 종료: 점수 {score} / {rounds} ==")
